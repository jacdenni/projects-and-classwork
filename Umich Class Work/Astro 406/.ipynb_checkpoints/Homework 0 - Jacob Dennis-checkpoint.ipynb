# %% [markdown]
# <i>Computing in My Life</i>

# %% [markdown]
# I am a current senior majoring in Astronomy, planning to graduate this May. Nearly all of my computing experience has come about in the past four years: I took Astro 361 (Astronomical Techniques) in the winter of 2015, which provided the basis of my skills with Python; this was suppelemented by EECS 183 (which provided mostly experience with C++) and Physics 411 (Intro to Computational Physics). Thus, pretty much all of my coding experience has been with Python on my 2012 MacBook Pro, running OS X El Capitan.

# %% [markdown]
# I am taking this class primarily because of how I have come to enjoy using and working with computers and programming to solve physics problems. (In retrospect, I probably should have gone for an EECS minor at the very least; however, I only really discovered this interest last year in Physics 411.) Thus, much of what I hope to get out of this class is a better understanding of how computational techniques can be used in physics and astronomy. I would also like to learn a bit about how I can use these techniques in future careers outside of research and graduate school. (My own plans post-graduation are still in the works - I am spending much of my time looking for jobs.)

# %%
from IPython.display import Image


print 'My aging laptop.'

Image('JacobDennisHomework0Photo.jpg')
# Out:
# My aging laptop.
